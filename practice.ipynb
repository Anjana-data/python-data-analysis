# %%
import pandas as pd

# %%
c_df=pd.read_csv('customer.csv')

# %%
c_df.head(n=5)
# Out:
#   customer_id  age_in_months  gender  occupation married registered_date  \
# 0        C754         255.67       F     Student       y       22-Apr-23
# 1        C854         251.25       F     Teacher       y       10-Mar-19
# 2        C132         214.90    male      Doctor       y       08-Jul-19
# 3        C833         524.94  female      Farmer       y       09-Oct-20
# 4        C928         634.65     fem  Unemployed       y       24-Dec-17
#
#   premium_status
# 0      not opted
# 1             no
# 2      not opted
# 3            yes
# 4             no

# %%
c_df.duplicated().any()
# Out:
# np.False_

# %%
c_df.duplicated(subset='customer_id').any()
# Out:
# np.True_

# %%
c_df=c_df.drop_duplicates(subset='customer_id')

# %%
c_df.shape
# Out:
# (569, 7)
